# %%
import numpy as np
import cv2
import os
import random
from matplotlib import pyplot as plt




from tensorflow.keras.models import Model;
from tensorflow.keras.layers import Layer,Conv2D,MaxPooling2D,Input,Flatten;
import tensorflow as tf
# inputimage = Input(shape=(...))  # Replace '...' with the actual shape of your input
# verificationImage = Input(shape=(...))

# Model(inputs=[inputimage,verificationImage], output =[1,0]);

gpus=tf.config.experimental.list_physical_devices("GPU")
for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu,True)


POS_PATH=os.path.join('data' ,'positive')
NEG_PATH=os.path.join('data', 'negative')
ANC_PATH=os.path.join('data' ,'anchor')

# os.makedirs(POS_PATH)
# os.makedirs(NEG_PATH)
# os.makedirs(ANC_PATH)

# if not os.path.exists(POS_PATH):
#     os.makedirs(POS_PATH)

# if not os.path.exists(NEG_PATH):
#     os.makedirs(NEG_PATH)

# if not os.path.exists(ANC_PATH):
#     os.makedirs(ANC_PATH)

print("Current Working Directory:", os.getcwd())
# !tar -xf lfw.tgz
print("Current Working Directory:", os.getcwd())

# Specify the full path to the 'lfw.tgz' file
file_path = 'lfw.tgz'  # Assuming the file is in the current working directory

# Print the full path to the file
print("Full File Path:", file_path)

# Check if the file exists
if os.path.exists(file_path):
    print("File exists!")
else:
    print("File not found.")

# Try to extract the archive using the tar command

# Assuming NEG_PATH is defined somewhere in your code
NEG_PATH = os.path.join('data', 'negative')

# Iterate through directories and files in 'lfw'
for directory in os.listdir('lfw'):
    directory_path = os.path.join('lfw', directory)
    
    if os.path.isdir(directory_path):
        for file in os.listdir(directory_path):
            file_path = os.path.join(directory_path, file)
            
            # Print each file in 'lfw' directory
            print("File in 'lfw':", file_path)
            
            # Assuming NEG_PATH is defined somewhere in your code
            NEW_PATH = os.path.join(NEG_PATH, file)
            
            # Move the file to the 'negative' directory
            try:
                os.replace(file_path, NEW_PATH)
                print(f"Moved {file} to {NEW_PATH}")
            except Exception as e:
                print(f"Error moving {file}: {e}")

# Print files in 'lfw' after moving
# for directory in os.listdir('lfw'):
#     for file in os.listdir(os.path.join('lfw', directory)):
#         print("File in 'lfw' after moving:", file)
        
          
cap = cv2.VideoCapture(4)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    cv2.imshow('Image Collection', frame)
    exFF = 0xFF 
    if cv2.waitKey(1) & exFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ----------------------------------------------------------------
# ModuleNotFoundError            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import cv2
#       3 import os
#       4 import random
#
# ModuleNotFoundError: No module named 'cv2'

# %%
piplist
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 piplist
#
# NameError: name 'piplist' is not defined

# %%
pip list
# Out:
# Package                       VersionNote: you may need to restart the kernel to use updated packages.
#
# ----------------------------- ---------------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.5
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-anon-usage           0.4.2
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.1
# anaconda-cloud-auth           0.1.3
# anaconda-navigator            2.5.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# ...

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
jupyter notebook
# Out:
#   Cell In[6], line 1
#     jupyter notebook
#             ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import cv2
import os
import random
from matplotlib import pyplot as plt




from tensorflow.keras.models import Model;
from tensorflow.keras.layers import Layer,Conv2D,MaxPooling2D,Input,Flatten;
import tensorflow as tf
# inputimage = Input(shape=(...))  # Replace '...' with the actual shape of your input
# verificationImage = Input(shape=(...))

# Model(inputs=[inputimage,verificationImage], output =[1,0]);

gpus=tf.config.experimental.list_physical_devices("GPU")
for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu,True)


POS_PATH=os.path.join('data' ,'positive')
NEG_PATH=os.path.join('data', 'negative')
ANC_PATH=os.path.join('data' ,'anchor')

# os.makedirs(POS_PATH)
# os.makedirs(NEG_PATH)
# os.makedirs(ANC_PATH)

# if not os.path.exists(POS_PATH):
#     os.makedirs(POS_PATH)

# if not os.path.exists(NEG_PATH):
#     os.makedirs(NEG_PATH)

# if not os.path.exists(ANC_PATH):
#     os.makedirs(ANC_PATH)

print("Current Working Directory:", os.getcwd())
# !tar -xf lfw.tgz
print("Current Working Directory:", os.getcwd())

# Specify the full path to the 'lfw.tgz' file
file_path = 'lfw.tgz'  # Assuming the file is in the current working directory

# Print the full path to the file
print("Full File Path:", file_path)

# Check if the file exists
if os.path.exists(file_path):
    print("File exists!")
else:
    print("File not found.")

# Try to extract the archive using the tar command

# Assuming NEG_PATH is defined somewhere in your code
NEG_PATH = os.path.join('data', 'negative')

# Iterate through directories and files in 'lfw'
for directory in os.listdir('lfw'):
    directory_path = os.path.join('lfw', directory)
    
    if os.path.isdir(directory_path):
        for file in os.listdir(directory_path):
            file_path = os.path.join(directory_path, file)
            
            # Print each file in 'lfw' directory
            print("File in 'lfw':", file_path)
            
            # Assuming NEG_PATH is defined somewhere in your code
            NEW_PATH = os.path.join(NEG_PATH, file)
            
            # Move the file to the 'negative' directory
            try:
                os.replace(file_path, NEW_PATH)
                print(f"Moved {file} to {NEW_PATH}")
            except Exception as e:
                print(f"Error moving {file}: {e}")

# Print files in 'lfw' after moving
# for directory in os.listdir('lfw'):
#     for file in os.listdir(os.path.join('lfw', directory)):
#         print("File in 'lfw' after moving:", file)
        
          
cap = cv2.VideoCapture(4)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    cv2.imshow('Image Collection', frame)
    exFF = 0xFF 
    if cv2.waitKey(1) & exFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ----------------------------------------------------------------
# ModuleNotFoundError            Traceback (most recent call last)
# Cell In[7], line 10
#       4 import random
#       5 from matplotlib import pyplot as plt
# ---> 10 from tensorflow.keras.models import Model;
#      11 from tensorflow.keras.layers import Layer,Conv2D,MaxPooling2D,Input,Flatten;
#      12 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
